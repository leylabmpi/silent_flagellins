# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#Var" data-toc-modified-id="Var-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Var</a></span></li><li><span><a href="#Init" data-toc-modified-id="Init-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Init</a></span></li><li><span><a href="#Load" data-toc-modified-id="Load-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Load</a></span></li><li><span><a href="#Summary" data-toc-modified-id="Summary-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Summary</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Lachno-abund" data-toc-modified-id="Lachno-abund-5.0.1"><span class="toc-item-num">5.0.1&nbsp;&nbsp;</span>Lachno abund</a></span></li><li><span><a href="#anx-taxa" data-toc-modified-id="anx-taxa-5.0.2"><span class="toc-item-num">5.0.2&nbsp;&nbsp;</span>anx taxa</a></span></li></ul></li></ul></li><li><span><a href="#sessionInfo" data-toc-modified-id="sessionInfo-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>sessionInfo</a></span></li></ul></div>

# %% [markdown]
# # Goal
#
# * plotting lachnospiraceae abundances for curatedMG dataset

# %% [markdown]
# # Var

# %%
data_dir = '/ebio/abt3_projects/databases_no-backup/curatedMetagenomicData/global_metagenomes/combined_GTDBr86/profiles/kraken/'
brk_file = file.path(data_dir, 'all-combined-bracken.tsv')
meta_file = file.path(data_dir, 'Global_metagenomes_Metadata.csv')
#data_dir = '/ebio/abt3_projects/databases_no-backup/curatedMetagenomicData/global_metagenomes/metadata/'
#meta_file = file.path(data_dir, 'Global_metagenomes_Metadata.csv')

# %% [markdown]
# # Init

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(data.table)
library(tidytable)
library(LeyLabRMisc)

# %%
df.dims()
setDTthreads(4)

# %% [markdown]
# # Load

# %%
# bracken abundances
brk = read_bracken(brk_file)
brk
# Out:
#           name                      taxonomy_id taxonomy_lvl Domain
# 1         Pedobacter sp. AJM        2003629     S            Bacteria
# 2         Bradyrhizobium sp. Ghvi   1855319     S            Bacteria
# ⋮         ⋮                         ⋮           ⋮            ⋮
# 110029275 Methylovulum miyakonense  645578      S            Bacteria
# 110029276 Nitritalea halalkaliphila 590849      S            Bacteria
#           Phylum         Class               Order
# 1         Bacteroidetes  Sphingobacteriia    Sphingobacteriales
# 2         Proteobacteria Alphaproteobacteria Rhizobiales
# ⋮         ⋮              ⋮                   ⋮
# 110029275 Proteobacteria Gammaproteobacteria Methylococcales
# 110029276 Bacteroidetes  Cytophagia          Cytophagales
#           Family              Genus          Species
# 1         Sphingobacteriaceae Pedobacter     Pedobacter sp. AJM
# 2         Bradyrhizobiaceae   Bradyrhizobium Bradyrhizobium sp. Ghvi
# ⋮         ⋮                   ⋮              ⋮
# 110029275 Methylococcaceae    Methylovulum   Methylovulum miyakonense
# 110029276 Cyclobacteriaceae   Nitritalea     Nitritalea halalkaliphila
#           Sample        Abundance
# 1         SAMEA5814677  0
# 2         SAMEA5814677  0
# ⋮         ⋮             ⋮
# 110029275 VTS_SS_9_1_18 0
# 110029276 VTS_SS_9_1_18 0

# %%
# sample metadata
meta = Fread(meta_file) %>%
    mutate.(Sample = gsub('[+-]+', '.', Sample)) %>%
    filter.(!is.na(non_westernized)) %>%
    mutate.(westernized = non_westernized == 'no') %>%
    select.(-non_westernized)
meta
# Out:
#      dataset_name  Sample            subjectID         disease age gender
# 1    AsnicarF_2017 MV_FEM1_t1Q14     MV_FEM1           healthy NA  female
# 2    AsnicarF_2017 MV_FEM2_t1Q14     MV_FEM2           healthy NA  female
# ⋮    ⋮             ⋮                 ⋮                 ⋮       ⋮   ⋮
# 3468 ZeeviD_2015   PNP_Validation_45 PNP_Validation_45 healthy NA  NA
# 3469 ZeeviD_2015   PNP_Validation_46 PNP_Validation_46 healthy NA  NA
#      country BMI alcohol disease_subtype ⋯ systolic_p creatine albumine
# 1    ITA     NA  NA      NA              ⋯ NA         NA       NA
# 2    ITA     NA  NA      NA              ⋯ NA         NA       NA
# ⋮    ⋮       ⋮   ⋮       ⋮               ⋱ ⋮          ⋮        ⋮
# 3468 ISR     NA  NA      NA              ⋯ NA         NA       NA
# 3469 ISR     NA  NA      NA              ⋯ NA         NA       NA
#      bilubirin smoker ever_smoker birth_control_pil c_peptide insulin_cat
# 1    NA        NA     NA          NA                NA        NA
# 2    NA        NA     NA          NA                NA        NA
# ⋮    ⋮         ⋮      ⋮           ⋮                 ⋮         ⋮
# 3468 NA        NA     NA          NA                NA        NA
# 3469 NA        NA     NA          NA                NA        NA
#      westernized
# 1    TRUE
# 2    TRUE
# ⋮    ⋮
# 3468 TRUE
# 3469 TRUE

# %% [markdown]
# # Summary

# %%
# sample overlap
overlap(brk$Sample, meta$Sample)
# Out:
# intersect(x,y): 3469
# setdiff(x,y): 2494
# setdiff(y,x): 0
# union(x,y): 5963

# %%
# joining abundances and metadata
brk %>% unique_n('samples', Sample)
brk = brk %>%
    inner_join.(meta %>% 
                    filter.(disease == 'healthy') %>%
                    select.(dataset_name, Sample, westernized, country),
                c('Sample')) 
brk %>% unique_n('samples', Sample)
# Out:
# No. of unique samples: 5963
# No. of unique samples: 2108

# %% [markdown]
# ### Lachno abund

# %%
# summarize by lachno
brk_s = brk %>%
    mutate.(taxonomy = ifelse(Family == 'Lachnospiraceae', Family, 'Other')) %>%
    summarize.(Abundance = sum(Abundance),
               .by=c(Sample, dataset_name, westernized, taxonomy, country))
brk_s
# Out:
#      Sample            dataset_name  westernized taxonomy        country
# 1    MV_FEM1_t1Q14     AsnicarF_2017 TRUE        Other           ITA
# 2    MV_FEM1_t1Q14     AsnicarF_2017 TRUE        Lachnospiraceae ITA
# ⋮    ⋮                 ⋮             ⋮           ⋮               ⋮
# 4215 PNP_Validation_46 ZeeviD_2015   TRUE        Other           ISR
# 4216 PNP_Validation_46 ZeeviD_2015   TRUE        Lachnospiraceae ISR
#      Abundance
# 1    0.96181
# 2    0.03802
# ⋮    ⋮
# 4215 0.95741
# 4216 0.04293

# %%
# plotting
X = brk_s %>%
    filter.(taxonomy == 'Lachnospiraceae') %>%
    select.(Sample, dataset_name, Abundance)

brk_sf = brk_s %>%
    inner_join.(X, c('Sample', 'dataset_name')) %>%
    mutate.(Abundance = Abundance * 100) %>%
    mutate.(X = -(westernized %>% as.factor %>% as.numeric) + 
                 -i.Abundance) %>%
    mutate.(Sample = reorder(Sample, X)) %>%
    rename.('Westernized' = westernized) %>%
    mutate.(taxonomy = factor(taxonomy, levels=c('Other', 'Lachnospiraceae')))

p = brk_sf %>%
    ggplot(aes(Sample, Abundance)) +
    geom_bar(stat='identity', aes(fill=taxonomy)) +
    geom_point(aes(y=-2, color=Westernized), shape='|', size=2) +
    scale_color_all('Westernized') +
    guides(color = guide_legend(override.aes = list(shape = 15))) +
    ggnewscale::new_scale_colour() +
    geom_point(aes(y=-6, color=country), shape='|', size=2) +
    scale_color_all('Country') +
    guides(color = guide_legend(override.aes = list(shape = 15))) +
    scale_y_continuous(expand=c(0,0), limits=c(-8,101)) +
    scale_fill_discrete('Taxon') +
    labs(y='Abundance (%)') +
    theme_bw() +
    theme(
        axis.title.x = element_blank(),
        axis.text.x = element_blank(),
        axis.ticks.x = element_blank(),
        legend.position='bottom',
        legend.box = 'vertical'
    ) 
p.dims(10,5)
plot(p)
# Out:
# plot without title

# %%
# boxplots
p = brk_s %>%
    filter.(taxonomy == 'Lachnospiraceae') %>%
    mutate.(Abundance = Abundance * 100) %>%
    mutate.(westernized = ifelse(westernized == TRUE, 'Westernized', 'Non-westernized')) %>%
    mutate.(median_abund = median(Abundance, na.rm=TRUE),
            .by=c(country)) %>%
    mutate.(country = reorder(country, -median_abund)) %>%
    ggplot(aes(country, Abundance)) +
    geom_boxplot() +
    facet_grid(. ~ westernized, scales='free_x', space='free_x') +
    labs(x='Country', y='Abundance (%)') +
    theme_bw()
p.dims(7,2.5)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### anx taxa

# %%
# summarize by lachno
to_keep = c('Oscillospiraceae', 'Lachnospiraceae')
brk_s = brk %>%
    mutate.(taxonomy = ifelse(Family %in% to_keep, Family, 'Other')) %>%
    summarize.(Abundance = sum(Abundance),
               .by=c(Sample, dataset_name, westernized, taxonomy, country))
brk_s$taxonomy %>% table
brk_s
# Out:
# .
#  Lachnospiraceae Oscillospiraceae            Other
#             2108             2108             2108
#      Sample            dataset_name  westernized taxonomy         country
# 1    MV_FEM1_t1Q14     AsnicarF_2017 TRUE        Other            ITA
# 2    MV_FEM1_t1Q14     AsnicarF_2017 TRUE        Lachnospiraceae  ITA
# ⋮    ⋮                 ⋮             ⋮           ⋮                ⋮
# 6323 PNP_Validation_46 ZeeviD_2015   TRUE        Lachnospiraceae  ISR
# 6324 PNP_Validation_46 ZeeviD_2015   TRUE        Oscillospiraceae ISR
#      Abundance
# 1    0.95405
# 2    0.03802
# ⋮    ⋮
# 6323 0.04293
# 6324 0.00422

# %%
# plotting
X = brk_s %>%
    filter.(taxonomy == 'Lachnospiraceae') %>%
    select.(Sample, dataset_name, Abundance)

brk_sf = brk_s %>%
    inner_join.(X, c('Sample', 'dataset_name')) %>%
    mutate.(Abundance = Abundance * 100) %>%
    mutate.(X = -(westernized %>% as.factor %>% as.numeric) + 
                 -i.Abundance) %>%
    mutate.(Sample = reorder(Sample, X)) %>%
    rename.('Westernized' = westernized) %>%
    mutate.(taxonomy = factor(taxonomy, 
                              levels=c('Other', 
                                       'Lachnospiraceae', 
                                       'Oscillospiraceae')))

p = brk_sf %>%
    ggplot(aes(Sample, Abundance)) +
    geom_bar(stat='identity', aes(fill=taxonomy)) +
    geom_point(aes(y=-2, color=Westernized), shape='|', size=2) +
    scale_color_all('Westernized') +
    guides(color = guide_legend(override.aes = list(shape = 15))) +
    ggnewscale::new_scale_colour() +
    geom_point(aes(y=-6, color=country), shape='|', size=2) +
    scale_color_all('Country') +
    guides(color = guide_legend(override.aes = list(shape = 15))) +
    scale_y_continuous(expand=c(0,0), limits=c(-8,101)) +
    scale_fill_discrete('Taxon') +
    labs(y='Abundance (%)') +
    theme_bw() +
    theme(
        axis.title.x = element_blank(),
        axis.text.x = element_blank(),
        axis.ticks.x = element_blank(),
        legend.position='bottom',
        legend.box = 'vertical'
    ) 
p.dims(10,5)
plot(p)
# Out:
# plot without title

# %%
# boxplots
p = brk_s %>%
    filter.(taxonomy %in% to_keep) %>%
    mutate.(Abundance = Abundance * 100) %>%
    mutate.(westernized = ifelse(westernized == TRUE, 'Westernized', 'Non-westernized')) %>%
    mutate.(median_abund = median(Abundance, na.rm=TRUE),
            .by=c(country)) %>%
    mutate.(country = reorder(country, -median_abund)) %>%
    ggplot(aes(country, Abundance, color=taxonomy)) +
    geom_boxplot() +
    facet_grid(. ~ westernized, scales='free_x', space='free_x') +
    labs(x='Country', y='Abundance (%)') +
    theme_bw()
p.dims(8,2.5)
plot(p)
# Out:
# plot without title

# %% [markdown]
# # sessionInfo

# %%
sessionInfo()
# Out:
# R version 4.1.0 (2021-05-18)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.5 LTS
#
# Matrix products: default
# BLAS/LAPACK: /ebio/abt3_projects/Anxiety_Twins_Metagenomes/envs/tidyverse-ecoPhy3/lib/libopenblasp-r0.3.15.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] LeyLabRMisc_0.1.9 tidytable_0.6.3   data.table_1.14.0 ggplot2_3.3.5
# [5] tidyr_1.1.3       dplyr_1.0.7
#
# loaded via a namespace (and not attached):
#  [1] RColorBrewer_1.1-2 pillar_1.6.1       compiler_4.1.0     base64enc_0.1-3
#  [5] tools_4.1.0        digest_0.6.27      uuid_0.1-4         jsonlite_1.7.2
#  [9] evaluate_0.14      lifecycle_1.0.0    tibble_3.1.3       gtable_0.3.0
# [13] pkgconfig_2.0.3    rlang_0.4.11       IRdisplay_1.0      cli_3.0.1
# [17] IRkernel_1.2       repr_1.1.3         withr_2.4.2        generics_0.1.0
# [21] vctrs_0.3.8        grid_4.1.0         tidyselect_1.1.1   ggnewscale_0.4.5
# [25] glue_1.4.2         R6_2.5.0           fansi_0.4.2        pbdZMQ_0.3-5
# [29] farver_2.1.0       purrr_0.3.4        magrittr_2.0.1     scales_1.1.1
# [33] ellipsis_0.3.2     htmltools_0.5.1.1  colorspace_2.0-2   labeling_0.4.2
# [37] utf8_1.2.2         munsell_0.5.0      crayon_1.4.1
